# %% [markdown]
# # Kagggle
# ## Data Visualization
# ## <font color=blue>Full step by step to author </font>
# https://www.kaggle.com/code/alexisbcook/hello-seaborn/tutorial
#
# ----
# # 1.Hello Seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# %config InlineBackend. figure_format = "retina"

# %% [markdown]
# * parse_dates=True
#   * This tells the notebook to understand the each row label as a date (as opposed to a number or other text with a different meaning).

# %%
fifa=pd.read_csv("fifa.csv",index_col="Date",parse_dates=True)

fifa.head()
# Out:
#              ARG  BRA   ESP   FRA  GER  ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0  2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0  2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0  3.0
# 1993-11-19   9.0  4.0   7.0  15.0  3.0  1.0
# 1993-12-23   8.0  3.0   5.0  15.0  1.0  2.0

# %%
sns.lineplot(data=fifa)

plt.legend(bbox_to_anchor =(1, 1.15), ncol = 1) 
plt.title("How FIFA rankings evolved over time")
# Out:
# Text(0.5, 1.0, 'How FIFA rankings evolved over time')

# %% [markdown]
# -----
#
# # 2.Line Charts

# %%
spotify_filepath = "spotify.csv"
spotify=pd.read_csv(spotify_filepath,index_col="Date",parse_dates=True)
spotify.tail()
# Out:
#             Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# Date
# 2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#             Unforgettable
# Date
# 2018-01-05      2869783.0
# 2018-01-06      2743748.0
# 2018-01-07      2441045.0
# 2018-01-08      2622693.0
# 2018-01-09      2627334.0

# %%
spotify.dtypes
# Out:
# Shape of You                  int64
# Despacito                   float64
# Something Just Like This    float64
# HUMBLE.                     float64
# Unforgettable               float64
# dtype: object

# %%
plt.figure(figsize=(14,6))
sns.lineplot(data=spotify)
plt.title("Daily Global Streams of Popular Songs in 2017-2018")
# Out:
# Text(0.5, 1.0, 'Daily Global Streams of Popular Songs in 2017-2018')

# %%
plt.figure(figsize=(14,6))

sns.lineplot(data=spotify["Unforgettable"],label="Unforgettable")
sns.lineplot(data=spotify["Something Just Like This"],label="Something Just Like This")
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Unforgettable'>

# %% [markdown]
# ----
#
# # 3.Bar Charts and Heatmaps

# %%
flightdelays=pd.read_csv("flight_delays.csv",index_col="Month")

flightdelays.head()
# Out:
#              AA        AS         B6        DL         EV         F9  \
# Month
# 1      6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 2      7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 3      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 4      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 5      5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
#
#              HA         MQ         NK         OO        UA        US  \
# Month
# 1      3.512640  18.164974  11.398054  10.889894  6.352729  3.107457
# 2      6.029967  21.301627  16.474466   9.588895  7.260662  7.114455
# 3      3.468383  11.018418  10.039118   3.181693  4.892212  3.330787
# 4      0.011022   5.131228   8.766224   3.223796  4.376092  2.660290
# 5      0.826426   5.466790  22.397347   4.141162  6.827695  0.681605
#
#              VX        WN
# Month
# 1      1.420702  3.389466
# 2      7.784410  3.501363
# 3      5.348207  3.263341
# ...

# %%
plt.figure(figsize=(14,8))
sns.lineplot(data=flightdelays)
plt.legend(bbox_to_anchor =(1.1, 0.75), ncol = 1) 
plt.ylabel("Arrival delay (in minutes)")
plt.title("Average Arrival Delay for Each Airline, by Month",fontsize=25)
# Out:
# Text(0.5, 1.0, 'Average Arrival Delay for Each Airline, by Month')

# %% [markdown]
# * Important Note:
#   * You must select the indexing column with flight_data.index, and it is not possible to use flight_data['Month'] (which will return an error). This is because when we loaded the dataset, the "Month" column was used to index the rows. We always have to use this special notation to select the indexing column.

# %%
plt.figure(figsize=(14,8))
sns.barplot(x=flightdelays.index,y=flightdelays["MQ"])
plt.ylabel("Arrival delay (in minutes)")
# Out:
# Text(0, 0.5, 'Arrival delay (in minutes)')

# %% [markdown]
# * annot=True
#   * This ensures that the values for each cell appear on the chart. (Leaving this out removes the numbers from each of the cells!)

# %%
plt.figure(figsize=(14,7))
sns.heatmap(data=flightdelays,annot=True)
plt.xlabel("Airline")
plt.title("Average Arrival Delay for Each Airline, by Month",fontsize=25)
# Out:
# Text(0.5, 1.0, 'Average Arrival Delay for Each Airline, by Month')

# %% [markdown]
# ----
#
# # 4.Scatter Plots & Color-coded scatter plots

# %%
insurancedata = pd.read_csv("insurance.csv")
insurancedata.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# * The scatterplot above suggests that body mass index (BMI) and insurance charges are positively correlated, where customers with higher BMI typically also tend to pay more in insurance costs. (This pattern makes sense, since high BMI is typically associated with higher risk of chronic disease.)
#
# * Use scatter plots to display the relationships between (not two, but...) three variables! One way of doing this is by color-coding the points.

# %%
sns.scatterplot(x=insurancedata["bmi"],
                y=insurancedata["charges"],
               hue=insurancedata['smoker'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %% [markdown]
# * To double-check the strength of this relationship, you might like to add a 【regression line迴歸線】, or the line that best fits the data. We do this by changing the command to 【sns.regplot】.

# %%
sns.regplot(x=insurancedata["bmi"],y=insurancedata["charges"])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %% [markdown]
# * Use the sns.lmplot command to add [two regression lines], corresponding to smokers and nonsmokers. (You'll notice that the regression line for smokers has a much "steeper slope陡坡", relative to the line for nonsmokers!)

# %%
sns.lmplot(x="bmi", y="charges", hue="smoker", data=insurancedata)

# %% [markdown]
# * To feature a categorical variable (like "smoker") on one of the main axes. We'll refer to this plot type as a categorical scatter plot, and we build it with the 【sns.swarmplot分簇散點圖】command.

# %%
sns.swarmplot(x=insurancedata['smoker'],
              y=insurancedata['charges'])
# Out:
# C:\Users\dream\.conda\envs\ai37\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 67.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='smoker', ylabel='charges'>

# %% [markdown]
# * stripplot (分布散點圖)
# ![image.png](attachment:image.png)

# %% [markdown]
# ----
#
# # 5.Distributions (Histograms&Density plots)

# %%
iris = pd.read_csv("iris.csv",index_col="Id")
iris.head()
# Out:
#     Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 1                 5.1               3.5                1.4               0.2
# 2                 4.9               3.0                1.4               0.2
# 3                 4.7               3.2                1.3               0.2
# 4                 4.6               3.1                1.5               0.2
# 5                 5.0               3.6                1.4               0.2
#
#         Species
# Id
# 1   Iris-setosa
# 2   Iris-setosa
# 3   Iris-setosa
# 4   Iris-setosa
# 5   Iris-setosa

# %% [markdown]
# * a=
#   * chooses the column we'd like to plot (in this case, we chose 'Petal Length (cm)').
# * kde=
#  * False is something we'll always provide when creating a histogram, as leaving it out will create a slightly different plot.

# %%
sns.distplot(a=iris["Petal Length (cm)"],kde=False)
# Out:
# C:\Users\dream\.conda\envs\ai37\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Petal Length (cm)'>

# %% [markdown]
# * kernel density estimate (KDE)
# * To make a KDE plot, we use the sns.kdeplot command. Setting shade=True colors the area below the curve (and data= has identical functionality as when we made the histogram above).

# %%
sns.kdeplot(data=iris['Petal Length (cm)'], shade=True)
# Out:
# <AxesSubplot:xlabel='Petal Length (cm)', ylabel='Density'>

# %% [markdown]
# ### 2D KDE plots
# * We're not restricted to a single column when creating a KDE plot. We can create a two-dimensional (2D) KDE plot with the sns.jointplot command.
#
# * In the plot below, the color-coding shows us how likely we are to see different combinations of sepal width and petal length, where darker parts of the figure are more likely.
#
#
#
# * in addition to the 2D KDE plot in the center,
#   * the curve at the top of the figure is a KDE plot for the data on the x-axis (in this case, iris_data['Petal Length (cm)']), and
#   * the curve on the right of the figure is a KDE plot for the data on the y-axis (in this case, iris_data['Sepal Width (cm)']).

# %%
sns.jointplot(x=iris['Petal Length (cm)'], y=iris['Sepal Width (cm)'], kind="kde")

# %% [markdown]
# ### Color-coded plots

# %%
irisset=pd.read_csv("iris_setosa.csv",index_col="Id")
irisver=pd.read_csv("iris_versicolor.csv",index_col="Id")
irisvir=pd.read_csv("iris_virginica.csv",index_col="Id")
irisset.head()
# Out:
#     Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 1                 5.1               3.5                1.4               0.2
# 2                 4.9               3.0                1.4               0.2
# 3                 4.7               3.2                1.3               0.2
# 4                 4.6               3.1                1.5               0.2
# 5                 5.0               3.6                1.4               0.2
#
#         Species
# Id
# 1   Iris-setosa
# 2   Iris-setosa
# 3   Iris-setosa
# 4   Iris-setosa
# 5   Iris-setosa

# %%
irisver.tail()
# Out:
#      Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 96                 5.7               3.0                4.2               1.2
# 97                 5.7               2.9                4.2               1.3
# 98                 6.2               2.9                4.3               1.3
# 99                 5.1               2.5                3.0               1.1
# 100                5.7               2.8                4.1               1.3
#
#              Species
# Id
# 96   Iris-versicolor
# 97   Iris-versicolor
# 98   Iris-versicolor
# 99   Iris-versicolor
# 100  Iris-versicolor

# %%
irisvir.sample(3)
# Out:
#      Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 149                6.2               3.4                5.4               2.3
# 111                6.5               3.2                5.1               2.0
# 133                6.4               2.8                5.6               2.2
#
#             Species
# Id
# 149  Iris-virginica
# 111  Iris-virginica
# 133  Iris-virginica

# %%
sns.distplot(a=irisset["Petal Length (cm)"],label="Iris_setosa",kde=False)
sns.distplot(a=irisver["Petal Length (cm)"],label="Iris_versicolor",kde=False)
sns.distplot(a=irisvir["Petal Length (cm)"],label="Iris_virginica",kde=False)

plt.title("Histogram of Petal Lengths, by Species")
plt.legend(bbox_to_anchor =(1, 1.05), ncol = 1)
# Out:
# C:\Users\dream\.conda\envs\ai37\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# * One interesting pattern that can be seen in plots is that the plants seem to belong to one of two groups, where Iris versicolor and Iris virginica seem to have similar values for petal length, while Iris setosa belongs in a category all by itself.
#
# * In fact, according to this dataset, we might even be able to classify any iris plant as Iris setosa (as opposed to Iris versicolor or Iris virginica) just by looking at the petal length: if the petal length of an iris flower is less than 2 cm, it's most likely to be Iris setosa!

# %%
sns.kdeplot(data=irisset["Petal Length (cm)"],label="Iris_setosa",shade=True)
sns.kdeplot(data=irisver["Petal Length (cm)"],label="Iris_versicolor",shade=True)
sns.kdeplot(data=irisvir["Petal Length (cm)"],label="Iris_virginica",shade=True)

plt.title("Distribution of Petal Lengths, by Species")
plt.legend(bbox_to_anchor =(1.35, 1.0), ncol = 1)

# %% [markdown]
# ----
#
# # 6.Choosing Plot Types and Custom Styles
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Themes
# (1)"darkgrid",
# (2)"whitegrid",
# (3)"dark",
# (4)"white",
# (5)"ticks"

# %%
spotify = pd.read_csv("spotify.csv", index_col="Date", parse_dates=True)
plt.figure(figsize=(14,6))
sns.set_style("whitegrid")  # write before lineplot
sns.lineplot(data=spotify)

plt.title("Daily Global Streams of Popular Songs in 2017-2018")
# Out:
# Text(0.5, 1.0, 'Daily Global Streams of Popular Songs in 2017-2018')
